# %%
#import libraries
import numpy as np

# %%
arr = np.array([10, 20, 30, 40, 50, 60, 70])
print(arr)
print('\n Average number', arr.mean())
# Out:
# [10 20 30 40 50 60 70]
#
#  Average number 40.0

# %%
#indexing
print(arr[3])
print(arr[-2])
print(arr[6])
print(arr[-4])
# Out:
# 40
# 60
# 70
# 40

# %%
#slicing
print(arr[1:6])
print(arr[6:])
print(arr[:7])
print(arr[-6:-1])
print(arr[7:])
print(arr[-1:-6])
# Out:
# [20 30 40 50 60]
# [70]
# [10 20 30 40 50 60 70]
# [20 30 40 50 60]
# []
# []
