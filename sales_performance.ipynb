# %%
#import libraries
import pandas as pd
import numpy as np

# %%
#load dataset
sales = pd.read_csv("data/customer_data_raw.csv")
sales.head(10)
# Out:
#    CustomerID       fullName  Gender     Age     Region    Product  Quantity  \
# 0       201.0  Alice Johnson       F      29      North     Laptop         1
# 1       202.0  micheal SMITH    Male  thirty      south      Phone         2
# 2       203.0      Sarah lee       F      26       east     Laptop         1
# 3       204.0      David-Kim       M      31       west     Tablet         3
# 4       205.0            NaN  Female      42      north  Earphones         5
# 5       206.0     john brown       m      27  marketing     Laptop         1
# 6         NaN    Emma Wilson       F      33       East    Charger         2
# 7       208.0      TOM davis       M      30      South     Laptop         1
# 8       209.0    Jane Miller  Female     NaN         HR      Phone         2
# 9       210.0   Chris taylor    male      28      south    Charger         3
#
#   Price($) PurchaseDate   Feedback IsMember
# 0  $850.50   2023/04/12       Good      Yes
# 1      300   2023-11-01  Excellent       no
# 2     $950   2024/01/18        NaN        Y
# 3      NaN   2022/09/25    Average        n
# 4       75   2021/07/05       Good      yes
# 5    1,200   2024/10/14       Poor       No
# 6       25   2022/12/01       Good      Yes
# 7      800   2023/03/22        NaN     True
# 8      310   2023/05/10        bad        N
# 9       30   2024/02/05  Excellent     TRUE

# %%
region = pd.read_csv("data/region_sales_data.csv")
region.head(10)
# Out:
#        Region  TargetSales($)         Manager                ContactEmail
# 0       north           12000   Grace Anthony   grace.anthony@company.com
# 1       south           10000     Paul Walker     paul_walker@company.com
# 2        east            8500       Diana Lee       diana.lee@company.com
# 3        west            9000        John Kim        john.kim@company.com
# 4     central            9500       Susan Ade       susan_ade@company.com
# 5  north-east            8700       Peter Obi       peter.obi@company.com
# 6  south-west            9100  Michael Adigun  michael.adigun@company.com
# 7  south-east            8800      Jane Stone      jane_stone@company.com
# 8  north-west            8900    Mary Daniels    mary.daniels@company.com
# 9    mid-west            8600    Henry Thomas    henry.thomas@company.com

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    9 non-null      float64
#  1   fullName      9 non-null      object
#  2   Gender        10 non-null     object
#  3   Age           9 non-null      object
#  4   Region        10 non-null     object
#  5   Product       10 non-null     object
#  6   Quantity      10 non-null     int64
#  7   Price($)      9 non-null      object
#  8   PurchaseDate  10 non-null     object
#  9   Feedback      8 non-null      object
#  10  IsMember      10 non-null     object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 1012.0+ bytes

# %%
sales.isnull().sum()
# Out:
# CustomerID      1
# fullName        1
# Gender          0
# Age             1
# Region          0
# Product         0
# Quantity        0
# Price($)        1
# PurchaseDate    0
# Feedback        2
# IsMember        0
# dtype: int64

# %%
#to rename the sales column
sales.rename(columns={
    'CustomerID': 'customer_id',
    'fullName': 'full_name',
    'Gender': 'gender',
    'Age': 'age',
    'Region': 'region',
    'Product': 'product',
    'Quantity': 'quantity',
    'Price($)': 'price',
    'PurchaseDate': 'purchase_date',
    'Feedback': 'feedback',
    'IsMember': 'is_member'
}, inplace=True)
sales.head()
# Out:
#    customer_id      full_name  gender     age region    product  quantity  \
# 0        201.0  Alice Johnson       F      29  North     Laptop         1
# 1        202.0  micheal SMITH    Male  thirty  south      Phone         2
# 2        203.0      Sarah lee       F      26   east     Laptop         1
# 3        204.0      David-Kim       M      31   west     Tablet         3
# 4        205.0            NaN  Female      42  north  Earphones         5
#
#      price purchase_date   feedback is_member
# 0  $850.50    2023/04/12       Good       Yes
# 1      300    2023-11-01  Excellent        no
# 2     $950    2024/01/18        NaN         Y
# 3      NaN    2022/09/25    Average         n
# 4       75    2021/07/05       Good       yes

# %%
#ensure consistent value
sales['full_name'] = sales['full_name'].str.title()
sales['full_name'] = sales['full_name'].str.replace('-', ' ')

sales.head(10)
# Out:
#    customer_id      full_name  gender     age     region    product  quantity  \
# 0        201.0  Alice Johnson       F      29      North     Laptop         1
# 1        202.0  Micheal Smith    Male  thirty      south      Phone         2
# 2        203.0      Sarah Lee       F      26       east     Laptop         1
# 3        204.0      David Kim       M      31       west     Tablet         3
# 4        205.0            NaN  Female      42      north  Earphones         5
# 5        206.0     John Brown       m      27  marketing     Laptop         1
# 6          NaN    Emma Wilson       F      33       East    Charger         2
# 7        208.0      Tom Davis       M      30      South     Laptop         1
# 8        209.0    Jane Miller  Female     NaN         HR      Phone         2
# 9        210.0   Chris Taylor    male      28      south    Charger         3
#
#      price purchase_date   feedback is_member
# 0  $850.50    2023/04/12       Good       Yes
# 1      300    2023-11-01  Excellent        no
# 2     $950    2024/01/18        NaN         Y
# 3      NaN    2022/09/25    Average         n
# 4       75    2021/07/05       Good       yes
# 5    1,200    2024/10/14       Poor        No
# 6       25    2022/12/01       Good       Yes
# 7      800    2023/03/22        NaN      True
# 8      310    2023/05/10        bad         N
# 9       30    2024/02/05  Excellent      TRUE

# %%
sales['gender'] = sales['gender'].str.lower()
sales['gender'] = sales['gender'].replace({
    'f':'F',
    'male':'M',
    'm':'M',
    'female':'F'
})
sales.head(10)
# Out:
#    customer_id      full_name gender     age     region    product  quantity  \
# 0        201.0  Alice Johnson      F      29      North     Laptop         1
# 1        202.0  Micheal Smith      M  thirty      south      Phone         2
# 2        203.0      Sarah Lee      F      26       east     Laptop         1
# 3        204.0      David Kim      M      31       west     Tablet         3
# 4        205.0            NaN      F      42      north  Earphones         5
# 5        206.0     John Brown      M      27  marketing     Laptop         1
# 6          NaN    Emma Wilson      F      33       East    Charger         2
# 7        208.0      Tom Davis      M      30      South     Laptop         1
# 8        209.0    Jane Miller      F     NaN         HR      Phone         2
# 9        210.0   Chris Taylor      M      28      south    Charger         3
#
#      price purchase_date   feedback is_member
# 0  $850.50    2023/04/12       Good       Yes
# 1      300    2023-11-01  Excellent        no
# 2     $950    2024/01/18        NaN         Y
# 3      NaN    2022/09/25    Average         n
# 4       75    2021/07/05       Good       yes
# 5    1,200    2024/10/14       Poor        No
# 6       25    2022/12/01       Good       Yes
# 7      800    2023/03/22        NaN      True
# 8      310    2023/05/10        bad         N
# 9       30    2024/02/05  Excellent      TRUE

# %%
sales['region'] = sales['region'].str.lower().str.strip()
sales.head(10)
# Out:
#    customer_id      full_name gender     age     region    product  quantity  \
# 0        201.0  Alice Johnson      F      29      north     Laptop         1
# 1        202.0  Micheal Smith      M  thirty      south      Phone         2
# 2        203.0      Sarah Lee      F      26       east     Laptop         1
# 3        204.0      David Kim      M      31       west     Tablet         3
# 4        205.0            NaN      F      42      north  Earphones         5
# 5        206.0     John Brown      M      27  marketing     Laptop         1
# 6          NaN    Emma Wilson      F      33       east    Charger         2
# 7        208.0      Tom Davis      M      30      south     Laptop         1
# 8        209.0    Jane Miller      F     NaN         hr      Phone         2
# 9        210.0   Chris Taylor      M      28      south    Charger         3
#
#      price purchase_date   feedback is_member
# 0  $850.50    2023/04/12       Good       Yes
# 1      300    2023-11-01  Excellent        no
# 2     $950    2024/01/18        NaN         Y
# 3      NaN    2022/09/25    Average         n
# 4       75    2021/07/05       Good       yes
# 5    1,200    2024/10/14       Poor        No
# 6       25    2022/12/01       Good       Yes
# 7      800    2023/03/22        NaN      True
# 8      310    2023/05/10        bad         N
# 9       30    2024/02/05  Excellent      TRUE

# %%
sales['region'] = sales['region'].str.lower().str.strip()
sales['region'] = sales['region'].replace({
    'marketing': np.nan,
    'hr': np.nan
})
sales.head(10)
# Out:
#    customer_id      full_name gender     age region    product  quantity  \
# 0        201.0  Alice Johnson      F      29  north     Laptop         1
# 1        202.0  Micheal Smith      M  thirty  south      Phone         2
# 2        203.0      Sarah Lee      F      26   east     Laptop         1
# 3        204.0      David Kim      M      31   west     Tablet         3
# 4        205.0            NaN      F      42  north  Earphones         5
# 5        206.0     John Brown      M      27    NaN     Laptop         1
# 6          NaN    Emma Wilson      F      33   east    Charger         2
# 7        208.0      Tom Davis      M      30  south     Laptop         1
# 8        209.0    Jane Miller      F     NaN    NaN      Phone         2
# 9        210.0   Chris Taylor      M      28  south    Charger         3
#
#      price purchase_date   feedback is_member
# 0  $850.50    2023/04/12       Good       Yes
# 1      300    2023-11-01  Excellent        no
# 2     $950    2024/01/18        NaN         Y
# 3      NaN    2022/09/25    Average         n
# 4       75    2021/07/05       Good       yes
# 5    1,200    2024/10/14       Poor        No
# 6       25    2022/12/01       Good       Yes
# 7      800    2023/03/22        NaN      True
# 8      310    2023/05/10        bad         N
# 9       30    2024/02/05  Excellent      TRUE

# %%
sales['is_member'] = sales['is_member'].astype(str).str.lower().str.strip()
sales['is_member'] = sales['is_member'].replace({
    'yes': True,
    'no': False,
    'n': False,
    'y': True,
    'true': True
})

sales.head(10)
# Out:
# C:\Users\ayode\AppData\Local\Temp\ipykernel_8900\3889288871.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   sales['is_member'] = sales['is_member'].replace({
#    customer_id      full_name gender     age region    product  quantity  \
# 0        201.0  Alice Johnson      F      29  north     Laptop         1
# 1        202.0  Micheal Smith      M  thirty  south      Phone         2
# 2        203.0      Sarah Lee      F      26   east     Laptop         1
# 3        204.0      David Kim      M      31   west     Tablet         3
# 4        205.0            NaN      F      42  north  Earphones         5
# 5        206.0     John Brown      M      27    NaN     Laptop         1
# 6          NaN    Emma Wilson      F      33   east    Charger         2
# 7        208.0      Tom Davis      M      30  south     Laptop         1
# 8        209.0    Jane Miller      F     NaN    NaN      Phone         2
# 9        210.0   Chris Taylor      M      28  south    Charger         3
#
#      price purchase_date   feedback  is_member
# 0  $850.50    2023/04/12       Good       True
# 1      300    2023-11-01  Excellent      False
# 2     $950    2024/01/18        NaN       True
# 3      NaN    2022/09/25    Average      False
# 4       75    2021/07/05       Good       True
# 5    1,200    2024/10/14       Poor      False
# 6       25    2022/12/01       Good       True
# 7      800    2023/03/22        NaN       True
# 8      310    2023/05/10        bad      False
# 9       30    2024/02/05  Excellent       True

# %%
sales['feedback'] = sales['feedback'].str.title()
sales.head(10)
# Out:
#    customer_id      full_name gender     age region    product  quantity  \
# 0        201.0  Alice Johnson      F      29  north     Laptop         1
# 1        202.0  Micheal Smith      M  thirty  south      Phone         2
# 2        203.0      Sarah Lee      F      26   east     Laptop         1
# 3        204.0      David Kim      M      31   west     Tablet         3
# 4        205.0            NaN      F      42  north  Earphones         5
# 5        206.0     John Brown      M      27    NaN     Laptop         1
# 6          NaN    Emma Wilson      F      33   east    Charger         2
# 7        208.0      Tom Davis      M      30  south     Laptop         1
# 8        209.0    Jane Miller      F     NaN    NaN      Phone         2
# 9        210.0   Chris Taylor      M      28  south    Charger         3
#
#      price purchase_date   feedback  is_member
# 0  $850.50    2023/04/12       Good       True
# 1      300    2023-11-01  Excellent      False
# 2     $950    2024/01/18        NaN       True
# 3      NaN    2022/09/25    Average      False
# 4       75    2021/07/05       Good       True
# 5    1,200    2024/10/14       Poor      False
# 6       25    2022/12/01       Good       True
# 7      800    2023/03/22        NaN       True
# 8      310    2023/05/10        Bad      False
# 9       30    2024/02/05  Excellent       True

# %%
#cleaning the age column
sales['age'] = sales['age'].replace({
    'thirty': 30,
    "Nan": np.nan
})
sales['age'] = pd.to_numeric(sales['age'], errors='coerce')
sales
# Out:
#    customer_id      full_name gender   age region    product  quantity  \
# 0        201.0  Alice Johnson      F  29.0  north     Laptop         1
# 1        202.0  Micheal Smith      M  30.0  south      Phone         2
# 2        203.0      Sarah Lee      F  26.0   east     Laptop         1
# 3        204.0      David Kim      M  31.0   west     Tablet         3
# 4        205.0            NaN      F  42.0  north  Earphones         5
# 5        206.0     John Brown      M  27.0    NaN     Laptop         1
# 6          NaN    Emma Wilson      F  33.0   east    Charger         2
# 7        208.0      Tom Davis      M  30.0  south     Laptop         1
# 8        209.0    Jane Miller      F   NaN    NaN      Phone         2
# 9        210.0   Chris Taylor      M  28.0  south    Charger         3
#
#      price purchase_date   feedback  is_member
# 0  $850.50    2023/04/12       Good       True
# 1      300    2023-11-01  Excellent      False
# 2     $950    2024/01/18        NaN       True
# 3      NaN    2022/09/25    Average      False
# 4       75    2021/07/05       Good       True
# 5    1,200    2024/10/14       Poor      False
# 6       25    2022/12/01       Good       True
# 7      800    2023/03/22        NaN       True
# 8      310    2023/05/10        Bad      False
# 9       30    2024/02/05  Excellent       True

# %%
#cleaning price column
sales['price'] = (
    sales['price'] 
    .astype(str)
    .str.replace('$', "", regex=False)
    .str.replace(",", "", regex=False)
)
sales['price'] = pd.to_numeric(sales['price'], errors='coerce')
sales['price'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 10 entries, 0 to 9
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 9 non-null      float64
# dtypes: float64(1)
# memory usage: 212.0 bytes

# %%
#cleanin the date column

from dateutil import parser

def date_parser(date_str):
    try:
        return parser.parse(date_str, dayfirst=True)
    except Exception:
        return pd.NAT
sales['purchase_date'] = sales['purchase_date'].apply(date_parser)
sales
# Out:
#    customer_id      full_name gender   age region    product  quantity  \
# 0        201.0  Alice Johnson      F  29.0  north     Laptop         1
# 1        202.0  Micheal Smith      M  30.0  south      Phone         2
# 2        203.0      Sarah Lee      F  26.0   east     Laptop         1
# 3        204.0      David Kim      M  31.0   west     Tablet         3
# 4        205.0            NaN      F  42.0  north  Earphones         5
# 5        206.0     John Brown      M  27.0    NaN     Laptop         1
# 6          NaN    Emma Wilson      F  33.0   east    Charger         2
# 7        208.0      Tom Davis      M  30.0  south     Laptop         1
# 8        209.0    Jane Miller      F   NaN    NaN      Phone         2
# 9        210.0   Chris Taylor      M  28.0  south    Charger         3
#
#     price purchase_date   feedback  is_member
# 0   850.5    2023-12-04       Good       True
# 1   300.0    2023-01-11  Excellent      False
# 2   950.0    2024-01-18        NaN       True
# 3     NaN    2022-09-25    Average      False
# 4    75.0    2021-05-07       Good       True
# 5  1200.0    2024-10-14       Poor      False
# 6    25.0    2022-01-12       Good       True
# 7   800.0    2023-03-22        NaN       True
# 8   310.0    2023-10-05        Bad      False
# 9    30.0    2024-05-02  Excellent       True

# %%
sales['customer_id'] = sales['customer_id'].fillna(207.0)
sales['full_name'] = sales['full_name'].fillna('Unknown')
sales['age'] = sales['age'].fillna(sales['age'].median())
sales['region'] = sales['region'].fillna(sales['region'].mode()[0])
sales['price'] = sales['price'].fillna(sales['price'].median())
sales['feedback'] = sales['feedback'].fillna("No Feedback")
sales
# Out:
#    customer_id      full_name gender   age region    product  quantity  \
# 0        201.0  Alice Johnson      F  29.0  north     Laptop         1
# 1        202.0  Micheal Smith      M  30.0  south      Phone         2
# 2        203.0      Sarah Lee      F  26.0   east     Laptop         1
# 3        204.0      David Kim      M  31.0   west     Tablet         3
# 4        205.0        Unknown      F  42.0  north  Earphones         5
# 5        206.0     John Brown      M  27.0  south     Laptop         1
# 6        207.0    Emma Wilson      F  33.0   east    Charger         2
# 7        208.0      Tom Davis      M  30.0  south     Laptop         1
# 8        209.0    Jane Miller      F  30.0  south      Phone         2
# 9        210.0   Chris Taylor      M  28.0  south    Charger         3
#
#     price purchase_date     feedback  is_member
# 0   850.5    2023-12-04         Good       True
# 1   300.0    2023-01-11    Excellent      False
# 2   950.0    2024-01-18  No Feedback       True
# 3   310.0    2022-09-25      Average      False
# 4    75.0    2021-05-07         Good       True
# 5  1200.0    2024-10-14         Poor      False
# 6    25.0    2022-01-12         Good       True
# 7   800.0    2023-03-22  No Feedback       True
# 8   310.0    2023-10-05          Bad      False
# 9    30.0    2024-05-02    Excellent       True

# %%
sales['total_sales'] = sales['quantity'] * sales['price']
sales
# Out:
#    customer_id      full_name gender   age region    product  quantity  \
# 0        201.0  Alice Johnson      F  29.0  north     Laptop         1
# 1        202.0  Micheal Smith      M  30.0  south      Phone         2
# 2        203.0      Sarah Lee      F  26.0   east     Laptop         1
# 3        204.0      David Kim      M  31.0   west     Tablet         3
# 4        205.0        Unknown      F  42.0  north  Earphones         5
# 5        206.0     John Brown      M  27.0  south     Laptop         1
# 6        207.0    Emma Wilson      F  33.0   east    Charger         2
# 7        208.0      Tom Davis      M  30.0  south     Laptop         1
# 8        209.0    Jane Miller      F  30.0  south      Phone         2
# 9        210.0   Chris Taylor      M  28.0  south    Charger         3
#
#     price purchase_date     feedback  is_member  total_sales
# 0   850.5    2023-12-04         Good       True        850.5
# 1   300.0    2023-01-11    Excellent      False        600.0
# 2   950.0    2024-01-18  No Feedback       True        950.0
# 3   310.0    2022-09-25      Average      False        930.0
# 4    75.0    2021-05-07         Good       True        375.0
# 5  1200.0    2024-10-14         Poor      False       1200.0
# 6    25.0    2022-01-12         Good       True         50.0
# 7   800.0    2023-03-22  No Feedback       True        800.0
# 8   310.0    2023-10-05          Bad      False        620.0
# 9    30.0    2024-05-02    Excellent       True         90.0

# %%
def age_group(age):
    if 18 <= age <= 25:
        return "Youth"
    elif 26 <= age <= 35:
        return "Adult"
    elif 36 <= age <= 50:
        return "Mature"
    else:
        return "Teenage"

sales['age_group'] = sales['age'].apply(age_group)
sales
# Out:
#    customer_id      full_name gender   age region    product  quantity  \
# 0        201.0  Alice Johnson      F  29.0  north     Laptop         1
# 1        202.0  Micheal Smith      M  30.0  south      Phone         2
# 2        203.0      Sarah Lee      F  26.0   east     Laptop         1
# 3        204.0      David Kim      M  31.0   west     Tablet         3
# 4        205.0        Unknown      F  42.0  north  Earphones         5
# 5        206.0     John Brown      M  27.0  south     Laptop         1
# 6        207.0    Emma Wilson      F  33.0   east    Charger         2
# 7        208.0      Tom Davis      M  30.0  south     Laptop         1
# 8        209.0    Jane Miller      F  30.0  south      Phone         2
# 9        210.0   Chris Taylor      M  28.0  south    Charger         3
#
#     price purchase_date     feedback  is_member  total_sales age_group
# 0   850.5    2023-12-04         Good       True        850.5     Adult
# 1   300.0    2023-01-11    Excellent      False        600.0     Adult
# 2   950.0    2024-01-18  No Feedback       True        950.0     Adult
# 3   310.0    2022-09-25      Average      False        930.0     Adult
# 4    75.0    2021-05-07         Good       True        375.0    Mature
# 5  1200.0    2024-10-14         Poor      False       1200.0     Adult
# 6    25.0    2022-01-12         Good       True         50.0     Adult
# 7   800.0    2023-03-22  No Feedback       True        800.0     Adult
# 8   310.0    2023-10-05          Bad      False        620.0     Adult
# 9    30.0    2024-05-02    Excellent       True         90.0     Adult
